# %% [markdown]
# <a href="https://colab.research.google.com/github/nagwai832/Business-Intelligence-Projects/blob/main/Netflix/Netflix_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Getting Dataset

# %%
import pandas as pd
Netflix = pd.read_csv('/content/8. Netflix Dataset.csv')
Netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ## Basic Information about datasets

# %%
Netflix.head()                                                                 # to show top 5 records of datasets
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
Netflix.tail()                                                                 # to show top 5 records of datasets
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
 Netflix.shape                                                              # to show No. of rows and columns
# Out:
# (7789, 11)

# %%
Netflix.size                                                                # to show total No. of values in datasets
# Out:
# 85679

# %%
Netflix.columns                                                              # to show columns name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
Netflix.dtypes                                                                # to show datatype of columns
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
Netflix.info()                                                                # to show indexes, columns , datatypes of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ## Duplicated Rows

# %%
Netflix[Netflix.duplicated()]                                                  # to check row is duplicated
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
Netflix.drop_duplicates()                                                     # remove duplicated rows
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ## Null Values

# %%
Netflix.isnull().sum()                                                         # show count of null values in each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ## using Heat Map to show null values

# %%
import seaborn as sns

# %%
sns.heatmap(Netflix.isnull())

# %% [markdown]
# ## For 'House of Cards' what is the show id and who is the director of this show ?

# %% [markdown]
# ### isin(): show all records of a particular string in any columns

# %%
Netflix[Netflix['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### str.contains():show all records of a particular string in any columns

# %%
Netflix[Netflix['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## In which year highest number of TV shows & movies were released ? with Bar Graph

# %%
Netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
from datetime import datetime
Netflix['Release_Date'] = pd.to_datetime(Netflix['Release_Date'])

# %%
Netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   datetime64[ns]
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 669.5+ KB

# %% [markdown]
# ### dt.year.value_counts(): count occurance of all individual years in date column

# %%
Netflix['Release_Date'].dt.year.value_counts()
# Out:
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Release_Date, dtype: int64

# %% [markdown]
# ### Bar Grah

# %%
Netflix['Release_Date'].dt.year.value_counts().plot(kind = 'bar')

# %% [markdown]
# ## How many movies and TV shows are in the dataset

# %% [markdown]
# value_counts(): count category data

# %%
Netflix['Category'].value_counts()
# Out:
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# groupby: count category data

# %%
Netflix.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# countplot: count category data

# %%
sns.countplot(Netflix['Category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Show all movies that were released in 2020

# %% [markdown]
# create new column

# %%
Netflix['Year'] = Netflix['Release_Date'].dt.year

# %%
Netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
Netflix['Year'].unique()
# Out:
# array([2020., 2016., 2018., 2017., 2019., 2021., 2015., 2013., 2011.,
#          nan, 2012., 2014., 2008., 2009., 2010.])

# %%
Netflix[Netflix['Year'] == 2020.0][Netflix['Category']== 'Movie']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
# ...

# %% [markdown]
# ## Show only the titles of all TV shows that were released in india only

# %%
Netflix[(Netflix['Category'] == 'TV Show') & (Netflix['Country'] == 'India' )]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ## Show top 10 directories, who gave the highest number of TV Shows and Movies to netflix?

# %%
Netflix['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %% [markdown]
# ## Show all the records where Category is Movie and type is comedies or country is United Kingdom

# %%
Netflix[(Netflix['Category'] == 'Movie') & ((Netflix['Type'] == 'Comedies' )| (Netflix['Country'] == 'United Kingdom'))]
# Out:
#      Show_Id Category                   Title                Director  \
# 19       s20    Movie                     '89                     NaN
# 33       s34    Movie            #realityhigh        Fernando Lebrija
# 72       s73    Movie                17 Again             Burr Steers
# 82       s83    Movie     2036 Origin Unknown           Hasraf Dulull
# 84       s85    Movie               21 & Over  Jon Lucas, Scott Moore
# ...      ...      ...                     ...                     ...
# 7634   s7633    Movie            Wine Country             Amy Poehler
# 7649   s7648    Movie           Without Gorky          Cosima Spender
# 7664   s7663    Movie                 Work It           Laura Terruso
# 7688   s7687    Movie  XV: Beyond the Tryline        Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu             James Brown
#
#                                                    Cast         Country  \
# ...

# %% [markdown]
# ## How many Movies/Shows , Tom Crulse was cast

# %% [markdown]
# ## Filtering

# %%
Netflix[Netflix['Cast'] == 'Tom Cruise'].value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# str.contains()

# %%
Netflix[Netflix['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-707d1ccf9cfd> in <module>()
# ----> 1 Netflix[Netflix['Cast'].str.contains('Tom Cruise')]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# ## Creating new dataFrame

# %% [markdown]
# ### data.dropna: drop all rows that contains all or any missing values

# %%
new_data = Netflix.dropna()
new_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#   Release_Date Rating  Duration  \
# 1   2016-12-23  TV-MA    93 min
# 2   2018-12-20      R    78 min
# 3   2017-11-16  PG-13    80 min
# 4   2020-01-01  PG-13   123 min
# 5   2017-07-01  TV-MA  1 Season
#
#                                                 Type  \
# ...

# %%
new_data[new_data['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    Year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %% [markdown]
# ## What are the different ratings defined by Netflix ?

# %%
Netflix['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ## How many movies got the 'TV-14' rating in canada ?

# %%
Netflix[((Netflix['Category'] == 'Movie')) & (Netflix['Country'] == 'Canada') & (Netflix['Rating'] == 'TV-14')].shape[0]
# Out:
# 11

# %% [markdown]
# ## How many TV Show got the R rating after year 2018 ?

# %%
Netflix[(Netflix['Category'] == 'TV Show') & (Netflix['Rating'] == 'R') & (Netflix['Year'] > 2018.0)].shape[0]
# Out:
# 1

# %% [markdown]
# ## What is the max duration of movie/show in netflix

# %% [markdown]
# str.split()

# %%
Netflix[['Minutes','units']] = Netflix['Duration'].str.split(' ', expand = True)
Netflix.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description    Year (Minutes, units)  \
# 0  In a future where the elite inhabit an island ...  2020.0     [4, Seasons]
# 1  After a devastating earthquake hits Mexico Cit...  2016.0        [93, min]
#
#   Minutes    units
# 0       4  Seasons
# 1      93      min

# %%
Netflix['Minutes'].max()
# Out:
# '99'

# %%
Netflix['Minutes'].mean()
# Out:
# inf

# %%
Netflix['Duration'].max()
# Out:
# '99 min'

# %%
Netflix['Duration'].min()
# Out:
# '1 Season'

# %% [markdown]
# ## Which individual country has the highest number of TV Shows

# %%
Netflix[(Netflix['Category'] == 'TV Show')]['Country'].value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# ## How can we sort dataset by year

# %%
Netflix.sort_values(by = 'Year' , ascending= True).head(10)
# Out:
#      Show_Id Category                                       Title  \
# 7115   s7114    Movie                        To and From New York
# 1765   s1766  TV Show                             Dinner for Five
# 5766   s5766    Movie                                    Splatter
# 3248   s3249    Movie                     Just Another Love Story
# 3840   s3841    Movie                 Mad Ron's Prevues from Hell
# 308     s309    Movie                    Adam: His Song Continues
# 7151   s7150    Movie                          Too Young the Hero
# 5042   s5042    Movie  Quiet Victory: The Charlie Wedemeyer Story
# 7232   s7231    Movie                        Triumph of the Heart
# 2041   s2042    Movie                               Even the Rain
#
#                   Director                                               Cast  \
# 7115  Sorin Dan Mihalcescu  Barbara King, Shaana Diya, John Krisiukenas, Y...
# 1765                   NaN                                                NaN
# ...

# %%
Netflix.sort_values(by = 'Year' , ascending= False).head(10)
# Out:
#      Show_Id Category               Title                      Director  \
# 7353   s7352    Movie             Unknown            Jaume Collet-Serra
# 2013   s2014    Movie    Enter the Dragon                 Robert Clouse
# 2349   s2350    Movie           Gangaajal                   Prakash Jha
# 1497   s1498    Movie      Cool Hand Luke              Stuart Rosenberg
# 1194   s1195    Movie   Can't Hardly Wait  Harry Elfont, Deborah Kaplan
# 104     s105    Movie  30 Minutes or Less               Ruben Fleischer
# 692     s693    Movie      Bad Grandpa .5                 Jeff Tremaine
# 5139   s5139    Movie          Redemption                 Steven Knight
# 3521   s3522    Movie              Lagaan            Ashutosh Gowariker
# 5521   s5521    Movie  Sex and the City 2          Michael Patrick King
#
#                                                    Cast  \
# 7353  Liam Neeson, Diane Kruger, January Jones, Aida...
# 2013  Bruce Lee, John Saxon, Jim Kelly, Ahna Capri, ...
# ...

# %% [markdown]
# Category is Movie and Type is Drama
# or
# Category is TV Show and Type is Kids

# %%
Netflix[(((Netflix['Category'] == 'Movie') & (Netflix['Type'] == 'Dramas')) | ((Netflix['Category'] == 'TV Show') & (Netflix['Type'] == 'Kids')))].head(10)
# Out:
#     Show_Id Category                           Title          Director  \
# 4        s5    Movie                              21    Robert Luketic
# 7        s8    Movie                             187    Kevin Reynolds
# 170    s171    Movie                    A Family Man     Mark Williams
# 232    s233    Movie      A Stoning in Fulham County     Larry Elikann
# 295    s296    Movie              Across Grace Alley     Ralph Macchio
# 308    s309    Movie        Adam: His Song Continues  Robert Markowitz
# 330    s331    Movie                       Aftermath    Elliott Lester
# 334    s335    Movie  Agatha and the Truth of Murder       Terry Loane
# 422    s423    Movie                All Together Now       Brett Haley
# 429    s430    Movie                 Alone in Berlin     Vincent Perez
#
#                                                   Cast  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
